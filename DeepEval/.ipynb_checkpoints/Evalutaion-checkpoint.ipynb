# %%
from deepeval.metrics import (AnswerRelevancyMetric, 
                              ContextualPrecisionMetric, 
                              ContextualRelevancyMetric,
                              FaithfulnessMetric,
                              GEval)
from deepeval.test_case import LLMTestCaseParams, LLMTestCase
from deepeval.dataset import Golden, EvaluationDataset
from deepeval.models import DeepEvalBaseLLM
from deepevals_script import Ollama
from dotenv import load_dotenv
load_dotenv()
import deepeval
import os
from langchain_ollama.llms import OllamaLLM
from Retrieval import Retrieval
from langchain_pinecone import PineconeVectorStore
from dotenv import load_dotenv
import torch
from langchain_huggingface import HuggingFaceEmbeddings
from Pincone import Pincone_vectorStore
import warnings
from operator import itemgetter
from langchain_core.output_parsers import StrOutputParser
from typing import List, Dict
from langchain_ollama import ChatOllama
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
#   Cell In[1], line 9
#     from deepevals_script import CustomChatOpenAI, OllamaLLM,
#                                                               ^
# SyntaxError: trailing comma not allowed without surrounding parentheses

# %%
# !deepeval set-ollama llama2:7b

# %%
model_local = CustomChatOpenAI(
                model_name="llama2.7b",
                openai_api_key="ollama",
                base_url="http://localhost:11434/v1/",
                temperature=0.7,
            )

# %%
from langchain_ollama import  ChatOllama, OllamaLLM
models = OllamaLLM(
    model="llama2:7b"
)

# %%
# model_ollama = Ollama(model=models, name="llama", tokenizer=None)

# %%
Device = "cuda" if torch.cuda.is_available else "cpu"
index_name="klasshour"
index= Pincone_vectorStore(index_name=index_name)
Embeddings = HuggingFaceEmbeddings(model_name = "sentence-transformers/all-mpnet-base-v2", model_kwargs= {"device":Device})
vector_store = PineconeVectorStore(embedding=Embeddings,index=index)
retrieval_obj = Retrieval(device=Device, index=index,Embeddings=Embeddings,vector_store=vector_store)
retrieval, prompt = retrieval_obj.get_retrieval()


model = OllamaLLM(model="llama2:7b",
                  temperature=0.7)
chain = (
    {
        "context": itemgetter("question") | retrieval,
        "question": itemgetter("question"),
    }
    | prompt
    | model
    | StrOutputParser()
)

result=chain.invoke({"question": "What is Temperature"})
print(result)

# %%
API_Key= os.getenv(key="confident_AI")
deepeval.login(api_key=API_Key)

# %%
llm = ChatOllama(
    base_url="http://localhost:11434",
    model="llama2:7b",
    temperature=0.5,
    max_token=250
)

# %% [markdown]
# ### Create a golden set evaluations dataset
# 1. input
# 2. expected_output

# %%
test_data = [{
    "input": "If a water wave travels through water, what changes might occur that will simulate a different medium?",
    "expected_output": "\nIf a water wave travels through water, several changes might occur that can simulate a different medium. Here are some possible scenarios:\n\n1. \
        Decrease in wave amplitude: As the water wave travels through a denser medium, such as a thicker layer of water or a different type of fluid, it may lose energy and decrease in amplitude. \
        This is because the dense medium can absorb more of the wave's energy, causing it to dissipate faster.\n2. Change in wave period: The period of the wave may increase as it travels through a denser medium. \
        This is because the density of the medium can slow down the wave's propagation, causing it to take longer to complete one cycle.\n3. Changes in wave shape: The wave shape may change as it travels through a denser medium. For example, \
        if the water wave is traveling through a layer of honey, it may become more distorted and lose its original shape due to the viscous nature of the honey.\n4. Reflection and refraction: \
        When a water wave reaches an interface between two media with different densities, it may be reflected or refracted. Reflection occurs when the wave bounces off the interface, \
        while refraction happens when the wave passes through the interface at a different angle. Both reflection and refraction can change the direction of the wave and affect its amplitude and period.\n5. \
        Dispersion: When a water wave travels through a medium with different densities, it may experience dispersion, which is the spreading of waves over time. This can cause the wave to lose its original \
        shape and become distorted as it propagates through the medium.\n6. Absorption: Some media, such as sand or clay, can absorb some of the wave's energy, causing it to decrease in amplitude. \
        This is known as absorption.\n7. Scattering: When a water wave encounters an obstacle or a boundary with a different density, it may be scattered in different directions. \
        This can cause the wave to lose its original shape and amplitude and create additional waves at different frequencies.\n8. \
        Turbulence: When a water wave travels through a turbulent medium, such as a river or a stormy ocean, it may become distorted and lose some of its energy due to the turbulent flow."
},
{
"input": "What are the implications of the discovery of numerous planets around nearby stars for the probability of extraterrestrial life?",
"expected_output":  "The discovery of numerous planets around nearby stars has significant implications for the probability of extraterrestrial life. Here are some of the key implications:\n\n1. Increased likelihood of life-supporting planets: \
``With the discovery of dozens of exoplanets around nearby stars, it is now estimated that a substantial portion of these stars may have planets with conditions favorable for life to evolve. This increases the probability of finding other life-forms in the universe.\n2. \
    Fermi Paradox resolved: The Fermi Paradox suggests that if advanced civilizations are plentiful in the universe, we should have seen some sign of them by now. However, with the discovery of numerous planets around nearby stars, \
    it is possible that advanced civilizations simply haven't been detectable yet.\n3. Evidence for the \"building blocks of life\" hypothesis: The discovery of exoplanets with conditions similar to those on Earth suggests that the building blocks of life are \
    common in the universe. This increases the likelihood of finding other life-forms that may have evolved similarly to how life did on Earth.\n4. Motivation for further research: With the discovery of numerous planets around nearby stars, \
    there is now renewed interest in searching for signs of extraterrestrial life using various detection methods such as the SETI Institute's Allen Telescope Array or NASA's upcoming James Webb Space Telescope.\n5. Impact on our understanding of the universe: \
    The discovery of numerous planets around nearby stars has significantly changed our understanding of the universe and its potential for life. It has also raised new questions about the possibility of extraterrestrial life and the likelihood of intelligent \
    civilizations existing elsewhere in the universe.\n\nIn conclusion, the discovery of numerous planets around nearby stars has significantly increased the probability of extraterrestrial life and has motivated further research into the possibility of \
    life existing elsewhere in the universe."
},
{
    "input":"An event is specified by its location and time (x, y, z, t) relative to one particular inertial frame of reference S. As an example, (x, y, z, t) could denote the position of a particle at time t, and we could be looking at these positions for many different times to follow the motion of the particle. Suppose a second frame of reference S\u2032 moves with velocity v with respect to the first. For simplicity, assume this relative velocity is along the x-axis. The relation between the time and coordinates in the two frames of reference is then x = x\u2032 + vt, y = y\u2032, z = z\u2032. Implicit in these equations is the assumption that time measurements made by observers in both S and S\u2032 are the same. That is, t = t\u2032.\n\nHow far does the particle travel as viewed from the particle\u2019s reference frame?",
    "expected_output":"\nIn the particle's own reference frame, it travels a distance of 2.50 km. This is because the particle's velocity is 0.750c, which means that it moves a distance of 0.750c \\* t in the direction of motion, where t is the time elapsed. \
        Since the time elapsed is 2.50 km \/ 0.750c = 3.2 km\/s, the particle travels a total distance of 2.50 km + 3.2 km\/s \\* t in its own reference frame.\n\nHowever, \
        an Earth-bound observer will measure a different distance due to the phenomenon of length contraction. Using the Lorentz transformation equations, we can calculate the distance measured by the Earth-bound observer as:\n\nx' = x - vt\ny = y\nz = z\n\nSubstituting \
        the given values, we get:\n\nx' = 2.50 km - (0.750c \\* t) = 2.50 km - t km\/s\n\nTherefore, the particle travels a distance of 2.50 km as measured by the Earth-bound observer."

}
]

# %%
# goldens = []
# for data in test_data:
#     golden = Golden(
#     input = data['input'],
#     expected_output = data['expected_output']
#     )
    
#     goldens.append(golden)
# dataset = EvaluationDataset(goldens=goldens)

# %%
dataset = EvaluationDataset()

# %%
dataset.pull("Rags_Eval_dataset")

# %%
dataset

# %%
for golden in dataset.goldens:
    test_cases = LLMTestCase(
        input=golden.input,
        actual_output=golden.expected_output
    )
    dataset.add_test_case(test_cases)

# %%
dataset

# %%
from langchain.chains import RetrievalQA

# %%
QA_Chain = RetrievalQA.from_chain_type(llm=llm, 
                                       retriever=retrieval)

# %%
response = QA_Chain("What is Temperature")

# %%
print(response)

# %%
def query_with_context(question):
    retrived = retrieval.get_relevant_documents(question)
    response = QA_Chain.run(question)
    return retrived, response

# %%
actual, query = query_with_context("Principle of relativity")
actual, query

# %%
from deepeval.dataset import Golden
from deepeval.test_case import LLMTestCase
from typing import List
def convert_goldens_to_test_cases(goldens: List[Golden]) -> List[LLMTestCase]:
    test_cases = []
    for golden in dataset.goldens:
        context, rag_response = query_with_context(golden.input)
        retrieval_texts = [str(content) for content in context]
        test_case = LLMTestCase(
            input=golden.input,
            actual_output=rag_response,
            expected_output=golden.expected_output,
            retrieval_context= retrieval_texts
        )
        test_cases.append(test_case)
    return test_cases

# %%
data = convert_goldens_to_test_cases(dataset)

# %%
data

# %%
# !deepeval set-local-model --model-name=llama2:7b --base-url="http://localhost:11434/" --api-key="ollama"

# %%
deepeval.evaluate(
    data, 
    metrics= [
        deepeval.metrics.AnswerRelevancyMetric(model=model_local),
        deepeval.metrics.FaithfulnessMetric(model=model_ollama),
        deepeval.metrics.ContextualPrecisionMetric(model=model_ollama),
       deepeval.metrics.ContextualRelevancyMetric(model=model_ollama)
    ]
)
